# %% [markdown]
# ## Notebook preparation
#
# This notebook illustrates the results of the commands in the [Illumina Overview Tutorial](http://qiime.org/tutorials/illumina_overview_tutorial.html). It makes use of the 12_10 release of the Greengenes reference OTUs. You can always find a link to the latest version of the reference OTUs on the [QIIME resources page](http://qiime.org/home_static/dataFiles.html).

# %% [markdown]
# ## Getting started
#
# We'll begin by downloading data and initializing some variables to configure our IPython computing environment. Don't edit anything in this first cell.

# %%
# !wget https://s3.amazonaws.com/qiime-tutorial/moving_pictures_tutorial.tgz
# !wget ftp://greengenes.microbio.me/greengenes_release/gg_12_10/gg_12_10_otus.tar.gz
# !tar -xzf moving_pictures_tutorial.tgz
# !tar -xzf gg_12_10_otus.tar.gz

# %%
from random import choice
from os import chdir, mkdir
from os.path import join
from IPython.display import FileLinks, FileLink

otu_base = "gg_12_10_otus/"
reference_seqs = join(otu_base,"rep_set/97_otus.fasta")
reference_tree = join(otu_base,"trees/97_otus.tree")
reference_tax = join(otu_base,"taxonomy/97_otu_taxonomy.txt")

# %% [markdown]
# Start by seeing what files are in our tutorial direcotry. We can do this using `ls` as we would on the command line, but in this case we prefix with an `!` to tell IPython that we're issuing a `bash` (i.e., command line) command, rather than a python command.

# %%
# !ls moving_pictures_tutorial

# %% [markdown]
# QIIME additionally supports more convenient output formattting for the IPython notebook so you can directly interact with or download your data.

# %%
FileLinks('moving_pictures_tutorial')

# %% [markdown]
# ## Demultiplexing and quality filtering seqeunces

# %%
# !split_libraries_fastq.py -o slout/ -i moving_pictures_tutorial/subsampled_fastq/subsampled_s_1_sequence.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_2_sequence.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_3_sequence.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_4_sequence.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_5_sequence.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_6_sequence.fastq -b moving_pictures_tutorial/subsampled_fastq/subsampled_s_1_sequence_barcodes.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_2_sequence_barcodes.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_3_sequence_barcodes.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_4_sequence_barcodes.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_5_sequence_barcodes.fastq,moving_pictures_tutorial/subsampled_fastq/subsampled_s_6_sequence_barcodes.fastq -m moving_pictures_tutorial/filtered_mapping_l1.txt,moving_pictures_tutorial/filtered_mapping_l2.txt,moving_pictures_tutorial/filtered_mapping_l3.txt,moving_pictures_tutorial/filtered_mapping_l4.txt,moving_pictures_tutorial/filtered_mapping_l5.txt,moving_pictures_tutorial/filtered_mapping_l6.txt

# %% [markdown]
# We often want to see the results of running a command. Here we can do that by calling our output formatter again, this time passing the output directory from the previous step.

# %%
FileLinks('slout/')

# %%
# !count_seqs.py -i slout/seqs.fna

# %% [markdown]
# ## OTU picking: using a closed-reference OTU picking protocol by searching reads agsint the Greengenes database, and discarding sequences that fail to hit at >=97% sequence identity.

# %%
# !pick_closed_reference_otus.py -o ucrC_fast/ -i slout/seqs.fna -r $reference_seqs -t $reference_tax -p moving_pictures_tutorial/ucrC_fast_params.txt

# %%
FileLinks('ucrC_fast/')
# Out:
# ucrC_fast/
#   log_20121217105117.txt
# ucrC_fast/uclust_ref_picked_otus/
#   otu_table.biom
#   seqs_clusters.uc
#   seqs_failures.txt
#   seqs_otus.log
#   seqs_otus.txt

# %%
# !print_biom_table_summary.py -i ucrC_fast/uclust_ref_picked_otus/otu_table.biom
# Out:
# Num samples: 61
# Num otus: 2815
# Num observations (sequences): 63206.0
# Table density (fraction of non-zero values): 0.0591
#
# Seqs/sample summary:
#  Min: 127.0
#  Max: 2461.0
#  Median: 890.0
#  Mean: 1036.16393443
#  Std. dev.: 743.558307554
#  Median Absolute Deviation: 609.0
#  Default even sampling depth in
#   core_qiime_analyses.py (just a suggestion): 127.0
#  Sample Metadata Categories: None provided
#  Observation Metadata Categories: taxonomy
#
# Seqs/sample detail:
#  L3S237: 127.0
#  L3S235: 177.0
#  L3S372: 196.0
#  L3S373: 225.0
#  L3S367: 247.0
#  L3S368: 250.0
#  L3S370: 255.0
#  L3S369: 268.0
#  L3S236: 277.0
#  L3S238: 277.0
#  L3S371: 281.0
#  L3S9: 282.0
#  L3S8: 286.0
#  L3S6: 295.0
#  L3S7: 302.0
#  L5S234: 362.0
#  L5S231: 373.0
#  L5S235: 405.0
#  L5S99: 419.0
#  L5S98: 429.0
#  L5S230: 431.0
#  L5S233: 452.0
#  L5S232: 454.0
#  L5S229: 496.0
#  L5S97: 501.0
#  L5S100: 515.0
#  L2S236: 593.0
#  L2S234: 765.0
#  L2S231: 788.0
#  L2S229: 885.0
#  L2S233: 890.0
#  L2S99: 946.0
#  L2S230: 963.0
#  L2S232: 965.0
#  L2S100: 1056.0
#  L1S4: 1057.0
#  L2S235: 1060.0
#  L2S97: 1087.0
#  L2S98: 1165.0
#  L1S3: 1193.0
#  L1S1: 1326.0
#  L1S131: 1528.0
#  L1S134: 1566.0
#  L1S132: 1684.0
#  L1S129: 1723.0
#  L1S135: 1736.0
#  L1S130: 1741.0
#  L4S146: 1845.0
#  L1S133: 1871.0
#  L1S2: 1882.0
#  L6S100: 1967.0
#  L1S136: 2004.0
#  L6S101: 2029.0
#  L4S144: 2128.0
#  L4S145: 2141.0
#  L6S102: 2162.0
#  L1S287: 2225.0
#  L6S103: 2304.0
#  L4S147: 2442.0
#  L1S289: 2446.0
#  L1S290: 2461.0

# %% [markdown]
# ## Create a single mapping file from the per-lane mapping files.

# %%
# !merge_mapping_files.py -o combined_mapping_file.txt -m moving_pictures_tutorial/filtered_mapping_l1.txt,moving_pictures_tutorial/filtered_mapping_l2.txt,moving_pictures_tutorial/filtered_mapping_l3.txt,moving_pictures_tutorial/filtered_mapping_l4.txt,moving_pictures_tutorial/filtered_mapping_l5.txt,moving_pictures_tutorial/filtered_mapping_l6.txt

# %%
# !head combined_mapping_file.txt
# Out:
# #SampleID	BarcodeSequence	LinkerPrimerSequence	days_since_epoch	SamplePlate	timestamp	SampleType	month	PrimerPlate	WellID	year	day	subject	Description
# L6S100	GTCGCTGTCTTC	GTGCCAGCMGCCGCGGTAA	14355	20	20090421	Tongue	4	5	d1	2009	21	2	RK_Tong_4_21_2009
# L2S229	CAACTCATCGTA	GTGCCAGCMGCCGCGGTAA	14355	7	20090421	L_palm	4	2	e5	2009	21	1	AB_L_Palm_4_21_2009
# L6S102	GTTGACGACAGC	GTGCCAGCMGCCGCGGTAA	14357	20	20090423	Tongue	4	5	f1	2009	23	2	RK_Tong_4_23_2009
# L6S103	TACGCGCTGAGA	GTGCCAGCMGCCGCGGTAA	14358	20	20090424	Tongue	4	5	g1	2009	24	2	RK_Tong_4_24_2009
# L3S369	ATACAGAGCTCC	GTGCCAGCMGCCGCGGTAA	14357	12	20090423	R_palm	4	2	a11	2009	23	1	AB_R_Palm_4_23_2009
# L3S368	CATCTGTAGCGA	GTGCCAGCMGCCGCGGTAA	14356	12	20090422	R_palm	4	2	h10	2009	22	1	AB_R_Palm_4_22_2009
# L2S100	ACGCTCATGGAT	GTGCCAGCMGCCGCGGTAA	14176	6	20081024	L_palm	10	1	d1	2008	24	1	AB_L_Palm_10_24_2008
# L3S373	CACATCTAACAC	GTGCCAGCMGCCGCGGTAA	14175	12	20081023	R_palm	10	2	e11	2008	23	2	RK_R_Palm_10_23_2008
# L3S370	ATCCTCAGTAGT	GTGCCAGCMGCCGCGGTAA	14358	12	20090424	R_palm	4	2	b11	2009	24	1	AB_R_Palm_4_24_2009

# %% [markdown]
# To view a single file (rather than a directory) we use the ``FileLink`` function instead of the ``FileLinks`` function.

# %%
FileLink('combined_mapping_file.txt')
# Out:
# /Users/caporaso/Dropbox/code/qiime/examples/ipynb/combined_mapping_file.txt

# %% [markdown]
# ## Computing beta (i.e., betwteen-sample) diversity using weighted and unweighted unifrac

# %%
# !beta_diversity_through_plots.py -o bdiv_even258/ -i ucrC_fast/uclust_ref_picked_otus/otu_table.biom -m combined_mapping_file.txt -t $reference_tree -e 258

# %%
FileLinks('bdiv_even258/')
# Out:
# bdiv_even258/
#   log_20121217105222.txt
#   otu_table_even258.biom
#   prefs.txt
#   unweighted_unifrac_dm.txt
#   unweighted_unifrac_pc.txt
#   weighted_unifrac_dm.txt
#   weighted_unifrac_pc.txt
# bdiv_even258/unweighted_unifrac_2d_continuous/
#   unweighted_unifrac_pc_2D_PCoA_plots.html
# bdiv_even258/unweighted_unifrac_2d_continuous/20121217105315KQ1GTmGZzZtoSZidf739/20121217105315iR5eANM1RR9u9BGi70s5/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/unweighted_unifrac_2d_continuous/20121217105315KQ1GTmGZzZtoSZidf739/20121217105316MYrl3RUTtOGG7HTSu6NN/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/unweighted_unifrac_2d_continuous/20121217105315KQ1GTmGZzZtoSZidf739/20121217105317u367twSOmISV6EBL7OAW/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258

#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/weighted_unifrac_2d_discrete/20121217105255mbborkADsF7rOafHbYYS/201212171053010gU2aUIQMKZa25Lmu0lc/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/weighted_unifrac_2d_discrete/20121217105255mbborkADsF7rOafHbYYS/20121217105302NBbKsrBg5MuUxKFGkcFB/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/weighted_unifrac_2d_discrete/20121217105255mbborkADsF7rOafHbYYS/201212171053030WBYU2dPeXCozQGKIR4G/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/weighted_unifrac_2d_discrete/20121217105255mbborkADsF7rOafHbYYS/201212171053042ylCboUVgUlLFxz4b1EK/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even258/weighted_unifrac_2d_discrete/js/
#   overlib.js
# bdiv_even258/weighted_unifrac_3d_continuous/
#   weighted_unifrac_pc_3D_PCoA_plots.html
# bdiv_even258/weighted_unifrac_3d_continuous/20121217105245TWR5PUdDHNQ19DgobOw5/
#   weighted_unifrac_pc.txt.kin
# bdiv_even258/weighted_unifrac_3d_continuous/jar/
#   king.jar
# bdiv_even258/weighted_unifrac_3d_discrete/
#   weighted_unifrac_pc_3D_PCoA_plots.html
# bdiv_even258/weighted_unifrac_3d_discrete/201212171052459eqV1wye0W7xu9HKHis2/
#   weighted_unifrac_pc.txt.kin
# bdiv_even258/weighted_unifrac_3d_discrete/jar/
#   king.jar

# %% [markdown]
# ## Summarize the taxonomic composition of the samples

# %%
# !summarize_taxa_through_plots.py -o taxa_summaries/ -i ucrC_fast/uclust_ref_picked_otus/otu_table.biom -m combined_mapping_file.txt

# %%
FileLinks('taxa_summaries/')
# Out:
# taxa_summaries/
#   log_20121217105347.txt
#   otu_table_L2.txt
#   otu_table_L3.txt
#   otu_table_L4.txt
#   otu_table_L5.txt
#   otu_table_L6.txt
# taxa_summaries/taxa_summary_plots/
#   area_charts.html
#   bar_charts.html
# taxa_summaries/taxa_summary_plots/charts/
#   43R0xWextTzqk3bfXlUHNi4WEZfYTl.pdf
#   4nxi9JmpzTSgrxZU88CPP19G4SgN4f.pdf
#   aFnGwZuHaU6iMuMrc39Thh82Y87kzF.pdf
#   bdqMDzeSfE3iJ0mRwa21N0kF3Z1Tzd.png
#   bdqMDzeSfE3iJ0mRwa21N0kF3Z1Tzd_legend.pdf
#   ckdwNsEzLtIes9jKSb1pCRzDd7Rgjh.pdf
#   dCz3DdlOkTfimCstf5DTZm6bP8KRz0.pdf
#   FjC1PQGDSCZAUKU9y1jGXkdhOaeLTO.png
#   FjC1PQGDSCZAUKU9y1jGXkdhOaeLTO_legend.pdf
#   I0KMhNmH6WHdFEUpoMb2xIg7LWGaUu.png
#   I0KMhNmH6WHdFEUpoMb2xIg7LWGaUu_legend.pdf
#   iLkWrWjP0U41yuXgnpy0IE1USNh6NZ.png
#   iLkWrWjP0U41yuXgnpy0IE1USNh6NZ_legend.pdf
#   IR3qfRBrSS5dkFY4pgPfKn1FjesHnJ.pdf
#   jNwMqI7r5R8B806r06GzNoB4MawRZj.png
#   jNwMqI7r5R8B806r06GzNoB4MawRZj_legend.pdf
#   Mc91NKsh7XTczCRZ9pwDfkQhcX1Gmz.pdf
#   Mwq3xxTtTGW4mgjrn6MxkjeTpRkBeW.pdf
#   MXTqS2IriQ60DuRaS18JcMjjlY8ws0.png
#   MXTqS2IriQ60DuRaS18JcMjjlY8ws0_legend.pdf
#   mzS3zjntEONxSEoa55yZl6PjWABDbt.png
#   mzS3zjntEONxSEoa55yZl6PjWABDbt_legend.pdf
#   OOsdYzDaCPuWZNcOaUg0kqbxFqccSp.png
#   OOsdYzDaCPuWZNcOaUg0kqbxFqccSp_legend.pdf
#   tISlaZkocL6xP5oio5pQWgJnsN9HFc.pdf
#   unkDX6Gy6NZSHCf9D4ehgdppTAe0mC.png
#   unkDX6Gy6NZSHCf9D4ehgdppTAe0mC_legend.pdf
#   WsMAleNantDXhoZ4JqLY3P8jdzsL80.png
#   WsMAleNantDXhoZ4JqLY3P8jdzsL80_legend.pdf
#   xhgDO3pJOjzLH9qme1PrYL9C2FQ60y.pdf
# taxa_summaries/taxa_summary_plots/css/
#   qiime_style.css
# taxa_summaries/taxa_summary_plots/js/
#   overlib.js
# taxa_summaries/taxa_summary_plots/raw_data/
#   otu_table_L2.txt
#   otu_table_L3.txt
#   otu_table_L4.txt
#   otu_table_L5.txt
#   otu_table_L6.txt

# %%
# !summarize_taxa_through_plots.py -o taxa_summaries_by_SampleType/ -i ucrC_fast/uclust_ref_picked_otus/otu_table.biom -m combined_mapping_file.txt -c "SampleType"

# %%
FileLinks('taxa_summaries_by_SampleType/')
# Out:
# taxa_summaries_by_SampleType/
#   log_20121217105559.txt
#   SampleType_otu_table.biom
#   SampleType_otu_table_L2.txt
#   SampleType_otu_table_L3.txt
#   SampleType_otu_table_L4.txt
#   SampleType_otu_table_L5.txt
#   SampleType_otu_table_L6.txt
# taxa_summaries_by_SampleType/taxa_summary_plots/
#   area_charts.html
#   bar_charts.html
# taxa_summaries_by_SampleType/taxa_summary_plots/charts/
#   1JUXWub9j8a2Al3UCm9g7NirNK4bzc.pdf
#   3eUu6Nte2ii6RMpqaF0tt1GN4bYsTX.pdf
#   cE6ZZSSi6x4ZUjz75Ruz9ZilGZ7aZW.png
#   cE6ZZSSi6x4ZUjz75Ruz9ZilGZ7aZW_legend.pdf
#   G0Iejzihk4q3tqgkFShacxIZa0AleK.pdf
#   gJO40iqp85uMTKJ9agIiR1r8FC7z59.png
#   gJO40iqp85uMTKJ9agIiR1r8FC7z59_legend.pdf
#   GUppJmA5bI4iCFQDXQmTO4XR4dhKJp.pdf
#   H5zJiPsuX03K3pzfeX3dKF4ObQI0Fg.pdf
#   HBo1BEY2sJf4DwRK9x95uZ4cJ0KKKc.png
#   HBo1BEY2sJf4DwRK9x95uZ4cJ0KKKc_legend.pdf
#   hntaL0bW31Xd1NNX91YgXs032kHZjp.pdf
#   K2QoHzz6sKO3K3pnD8B0BiAmirIFrz.pdf
#   mi3k5qciUwjGwCzpN9OsFJxOzWX0n7.png
#   mi3k5qciUwjGwCzpN9OsFJxOzWX0n7_legend.pdf
#   nnDkFEf0ihXQ0Y1qgMLZeAmN1DhlbI.pdf
#   r58OtZM033jHOazpEuRCiN8Iax3NJs.png
#   r58OtZM033jHOazpEuRCiN8Iax3NJs_legend.pdf
#   sBZ8y0fHNxFMSsT8KNuUIZKAE5HuEa.png
#   sBZ8y0fHNxFMSsT8KNuUIZKAE5HuEa_legend.pdf
#   synxy9pDcR4r4NpQKtkc1cHaQnX4pr.pdf
#   uoDJ5B8s7CyA3r76Q2M0SGY4U0yfkF.png
#   uoDJ5B8s7CyA3r76Q2M0SGY4U0yfkF_legend.pdf
#   wl6DdDGYD41bnNgkC2iy9Yqs2FOnWz.png
#   wl6DdDGYD41bnNgkC2iy9Yqs2FOnWz_legend.pdf
#   XjoiRz2CfpKoek9dZNxllKO6gGa2YG.png
#   XjoiRz2CfpKoek9dZNxllKO6gGa2YG_legend.pdf
#   YX6qfyiD2ZT8yTijsS0zFDu3ZlWBTM.png
#   YX6qfyiD2ZT8yTijsS0zFDu3ZlWBTM_legend.pdf
#   Z99QzJwr93Q3nnmAnQH2G7YjL42AUa.pdf
# taxa_summaries_by_SampleType/taxa_summary_plots/css/
#   qiime_style.css
# taxa_summaries_by_SampleType/taxa_summary_plots/js/
#   overlib.js
# taxa_summaries_by_SampleType/taxa_summary_plots/raw_data/
#   SampleType_otu_table_L2.txt
#   SampleType_otu_table_L3.txt
#   SampleType_otu_table_L4.txt
#   SampleType_otu_table_L5.txt
#   SampleType_otu_table_L6.txt

# %% [markdown]
# ## Comparing Illumina results with 454 results: Procrustes analysis

# %% [markdown]
# We'll begin by performing the same steps as above on the 454 data: we'll pick OTUs and compute UniFrac principal coordinate plots.

# %%
# !pick_closed_reference_otus.py -i moving_pictures_tutorial/subsampled_454_seqs.fna -o 454_ucrC_fast/ -r $reference_seqs -t $reference_tax -p moving_pictures_tutorial/ucrC_fast_params.txt

# %%
FileLinks('454_ucrC_fast/')
# Out:
# 454_ucrC_fast/
#   log_20121217112147.txt
# 454_ucrC_fast/uclust_ref_picked_otus/
#   otu_table.biom
#   subsampled_454_seqs_clusters.uc
#   subsampled_454_seqs_failures.txt
#   subsampled_454_seqs_otus.log
#   subsampled_454_seqs_otus.txt

# %%
# !print_biom_table_summary.py -i 454_ucrC_fast/uclust_ref_picked_otus/otu_table.biom
# Out:
# Num samples: 61
# Num otus: 1470
# Num observations (sequences): 20074.0
# Table density (fraction of non-zero values): 0.0514
#
# Seqs/sample summary:
#  Min: 147.0
#  Max: 548.0
#  Median: 277.0
#  Mean: 329.081967213
#  Std. dev.: 121.839896973
#  Median Absolute Deviation: 96.0
#  Default even sampling depth in
#   core_qiime_analyses.py (just a suggestion): 147.0
#  Sample Metadata Categories: None provided
#  Observation Metadata Categories: taxonomy
#
# Seqs/sample detail:
#  F4.TONG.04.21.09: 147.0
#  M3.RPAL.04.22.09: 169.0
#  M3.RPAL.04.21.09: 174.0
#  M3.TONG.04.21.09: 181.0
#  F4.FECE.04.22.09: 188.0
#  M3.FECE.04.21.09: 189.0
#  M3.TONG.04.24.09: 191.0
#  F4.LPAL.04.24.09: 192.0
#  F4.LPAL.04.21.09: 193.0
#  F4.RPAL.04.21.09: 197.0
#  F4.TONG.04.23.09: 200.0
#  F4.RPAL.04.22.09: 202.0
#  F4.TONG.04.24.09: 203.0
#  M3.LPAL.04.23.09: 203.0
#  M3.LPAL.04.21.09: 205.0
#  F4.RPAL.04.23.09: 210.0
#  M3.RPAL.04.24.09: 211.0
#  F4.LPAL.04.23.09: 215.0
#  M3.FECE.04.24.09: 232.0
#  F4.RPAL.04.24.09: 234.0
#  M3.RPAL.04.23.09: 234.0
#  F4.TONG.04.22.09: 235.0
#  F4.FECE.04.24.09: 236.0
#  F4.LPAL.04.22.09: 240.0
#  M3.LPAL.04.24.09: 252.0
#  M3.LPAL.04.22.09: 254.0
#  F4.FECE.04.23.09: 264.0
#  M3.FECE.04.22.09: 265.0
#  M3.TONG.04.23.09: 265.0
#  F4.FECE.04.21.09: 276.0
#  M3.TONG.04.22.09: 277.0
#  F4Fcsw1021: 345.0
#  F4Plml1021: 350.0
#  M3Plml1022: 363.0
#  M3Plml1021: 380.0
#  F4Tong1023: 383.0
#  F4Plmr1022: 401.0
#  M3Plmr1021: 403.0
#  F4Plmr1021: 407.0
#  M3Plml1024: 410.0
#  F4Tong1021: 413.0
#  F4Plml1023: 420.0
#  F4Plmr1024: 431.0
#  M3Tong1023: 431.0
#  F4Plmr1023: 435.0
#  M3Tong1021: 441.0
#  M3Fcsw1021: 444.0
#  F4Plml1022: 450.0
#  F4Tong1022: 453.0
#  M3Plmr1022: 468.0
#  M3Fcsw1022: 471.0
#  F4Fcsw1024: 481.0
#  M3Plml1023: 481.0
#  F4Plml1024: 484.0
#  M3Fcsw1023: 491.0
#  F4Fcsw1022: 497.0
#  M3Tong1022: 503.0
#  F4Fcsw1023: 510.0
#  F4Tong1024: 518.0
#  M3Fcsw1024: 528.0
#  M3Plmr1023: 548.0

# %%
# !beta_diversity_through_plots.py -o bdiv_even135/ -i 454_ucrC_fast/uclust_ref_picked_otus/otu_table.biom -e 135 -t $reference_tree -m moving_pictures_tutorial/454_map.txt

# %%
FileLinks('bdiv_even135/')
# Out:
# bdiv_even135/
#   log_20121217112231.txt
#   otu_table_even135.biom
#   prefs.txt
#   unweighted_unifrac_dm.txt
#   unweighted_unifrac_pc.txt
#   weighted_unifrac_dm.txt
#   weighted_unifrac_pc.txt
# bdiv_even135/unweighted_unifrac_2d_continuous/
#   unweighted_unifrac_pc_2D_PCoA_plots.html
# bdiv_even135/unweighted_unifrac_2d_continuous/20121217112308Gx7BcMCO3kQdG2mQvGgw/20121217112308WWrWgCkK16c9CYrGNGH2/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/unweighted_unifrac_2d_continuous/20121217112308Gx7BcMCO3kQdG2mQvGgw/201212171123093w2seRyVTFLBS0AUqgd1/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/unweighted_unifrac_2d_continuous/20121217112308Gx7BcMCO3kQdG2mQvGgw/20121217112310XVUMDbrr1x2HY1DzRuiF/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_

#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_continuous/js/
#   overlib.js
# bdiv_even135/weighted_unifrac_2d_discrete/
#   weighted_unifrac_pc_2D_PCoA_plots.html
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112252Blq2SZ9XYEmdYVrgpRhl/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112253OSnn74QWpfEbFctakmB0/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112254a0T1RtenEMDrHfNDZ7a7/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112255fixCXYoVNbPRlS34GAKT/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112256HVoWvab5UIiPFlN0b71u/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/20121217112252Xs0gtUYKX5E7vFxs5RUZ/20121217112257gDVw4d7LWRtrTIg930Xh/
#   PC1_vs_PC2_plot.png
#   PC1_vs_PC3_plot.png
#   PC1vsPC2plot.eps.gz
#   PC1vsPC3plot.eps.gz
#   PC3_vs_PC2_plot.png
#   PC3vsPC2plot.eps.gz
# bdiv_even135/weighted_unifrac_2d_discrete/js/
#   overlib.js
# bdiv_even135/weighted_unifrac_3d_continuous/
#   weighted_unifrac_pc_3D_PCoA_plots.html
# bdiv_even135/weighted_unifrac_3d_continuous/20121217112245CuerGV6WqKArgLTVLAnu/
#   weighted_unifrac_pc.txt.kin
# bdiv_even135/weighted_unifrac_3d_continuous/jar/
#   king.jar
# bdiv_even135/weighted_unifrac_3d_discrete/
#   weighted_unifrac_pc_3D_PCoA_plots.html
# bdiv_even135/weighted_unifrac_3d_discrete/20121217112246fg3tyMAPmwt7sV3KbxZV/
#   weighted_unifrac_pc.txt.kin
# bdiv_even135/weighted_unifrac_3d_discrete/jar/
#   king.jar

# %% [markdown]
# Next, we'll perform the Procustes transformation, and generate a Procrustes plot.

# %%
# !transform_coordinate_matrices.py -o 454_v_illumina/ -i bdiv_even258/unweighted_unifrac_pc.txt,bdiv_even135/unweighted_unifrac_pc.txt -s moving_pictures_tutorial/procrustes_sid_map.txt -r 100

# %%
FileLinks('454_v_illumina/')
# Out:
# 454_v_illumina/
#   pc1_transformed.txt
#   pc2_transformed.txt
#   unweighted_unifrac_pc_unweighted_unifrac_pc_procrustes_results.txt

# %%
# !compare_3d_plots.py -o 454_v_illumina/plots/ -i 454_v_illumina/pc1_transformed.txt,454_v_illumina/pc2_transformed.txt -m moving_pictures_tutorial/procrustes_metadata_map.txt --custom_axes days_since_epoch

# %%
FileLinks('454_v_illumina/plots/')
# Out:
# 454_v_illumina/plots/
#   pc1_transformed_3D_PCoA_plots.html
# 454_v_illumina/plots/20121217112410BILqCeQfIrn6lDlamg0n/
#   pc1_transformed.txt.kin
# 454_v_illumina/plots/jar/
#   king.jar
